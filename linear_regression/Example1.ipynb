# %%
# %matplotlib inline

import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.cross_validation import train_test_split
from sklearn import linear_model

# %%
# Import raw data, inspect head
sales = pd.read_csv('../data/Housing.csv')
sales.head()
# Out:
#    Unnamed: 0    price  lotsize  bedrooms  bathrms  stories driveway recroom  \
# 0           1  42000.0     5850         3        1        2      yes      no
# 1           2  38500.0     4000         2        1        1      yes      no
# 2           3  49500.0     3060         3        1        1      yes      no
# 3           4  60500.0     6650         3        1        2      yes     yes
# 4           5  61000.0     6360         2        1        1      yes      no
#
#   fullbase gashw airco  garagepl prefarea
# 0      yes    no    no         1       no
# 1       no    no    no         0       no
# 2       no    no    no         0       no
# 3       no    no    no         0       no
# 4       no    no    no         0       no

# %%
# Create basic Scatter Plot

plt.scatter(x= sales.lotsize, 
            y= sales.price, 
            s= 100, 
            alpha= 0.5, 
            c= 'blue')

# %%
# Divide data into training and test sets
train_data, test_data = train_test_split(sales, test_size= 0.2, random_state= 0)  #random_state==seed
train_data.head()
# Out:
#      Unnamed: 0     price  lotsize  bedrooms  bathrms  stories driveway  \
# 118         119  106500.0     4300         3        2        2      yes
# 400         401   92500.0     7410         3        1        1      yes
# 543         544  103000.0     6000         3        2        4      yes
# 202         203   50000.0     3480         3        1        1       no
# 165         166   62000.0     4075         3        1        1      yes
#
#     recroom fullbase gashw airco  garagepl prefarea
# 118      no      yes    no    no         1       no
# 400     yes      yes    no   yes         2      yes
# 543     yes       no    no   yes         1       no
# 202      no       no    no   yes         0       no
# 165     yes      yes    no    no         2       no

# %%
x_train = np.matrix(train_data.lotsize)
y_train = np.matrix(train_data.price)

x_test = np.matrix(test_data.lotsize)
y_test = np.matrix(test_data.price)

# %%
# Create and fit basic linear model

# Create linear regression object
regr = linear_model.LinearRegression()

# Train model using training set
regr.fit(x_train, y_train)

# Print Coefficients
#print('Coefficients:', regr.coef_)


plt.scatter(x_test, y_test)
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/scipy/linalg/basic.py:884: RuntimeWarning: internal gelsd driver lwork query error, required iwork dimension not returned. This is likely the result of LAPACK bug 0038, fixed in LAPACK 3.2.2 (released July 21, 2010). Falling back to 'gelss' driver.
#   warnings.warn(mesg, RuntimeWarning)

# %%
sns.pairplot(train_data, x_vars=['lotsize', 'bedrooms', 'bathrms'], y_vars= 'price', size= 7, kind='reg')

# %%
pred_train = regr.predict(x_train)
pred_train
# Out:
# array([[ 106500.,   92500.,  103000.,   50000.,   62000.,   87000.,
#           74900.,   50000.,  113000.,   75000.,  120000.,  133000.,
#           90000.,   95500.,   92000.,   90000.,   80000.,   47000.,
#           94000.,   60000.,   80000.,  117000.,   50000.,  105000.,
#           87000.,   52000.,   89000.,   33000.,   69000.,   75000.,
#           65000.,   58500.,   71000.,   60500.,   79000.,   59900.,
#          140000.,   38000.,   45000.,   84900.,   54800.,   57000.,
#           53500.,  175000.,   83000.,   85000.,   25245.,   57250.,
#           48000.,   66000.,   83800.,   86900.,   55000.,   83900.,
#           49000.,   60000.,   82000.,   50000.,  145000.,   62500.,
#           64000.,   34000.,   60000.,   49000.,   70000.,   48000.,
#          105000.,   30000.,   53900.,   54000.,   53000.,   91500.,
#           42500.,   42000.,   68000.,   25000.,   32000.,   32500.,
#           60000.,   62000.,   78900.,   61000.,  120000.,   45000.,
# ...
